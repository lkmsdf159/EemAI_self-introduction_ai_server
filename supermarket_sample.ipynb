# %% [markdown]
# <a href="https://colab.research.google.com/github/lkmsdf159/Colleage-/blob/main/supermarket_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx")

print(df)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
import pandas as pd
df1 = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx", sheet_name="Orders")
df1.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import pandas as pd
df2 = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx", sheet_name="People")
df2.head(4)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
import pandas as od
df3 = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx", sheet_name="Returns")
df3.head(5)
# Out:
#   Returned        Order ID
# 0      Yes  CA-2017-153822
# 1      Yes  CA-2017-129707
# 2      Yes  CA-2014-152345
# 3      Yes  CA-2015-156440
# 4      Yes  US-2017-155999

# %%
x=df1["Customer Name"]
x
# Out:
# 0            Claire Gute
# 1            Claire Gute
# 2        Darrin Van Huff
# 3         Sean O'Donnell
# 4         Sean O'Donnell
#               ...
# 9989    Tom Boeckenhauer
# 9990         Dave Brooks
# 9991         Dave Brooks
# 9992         Dave Brooks
# 9993        Chris Cortes
# Name: Customer Name, Length: 9994, dtype: object

# %%
len(x)
# Out:
# 9994

# %%
y=df1['Profit']
y
# Out:
# 0        41.9136
# 1       219.5820
# 2         6.8714
# 3      -383.0310
# 4         2.5164
#           ...
# 9989      4.1028
# 9990     15.6332
# 9991     19.3932
# 9992     13.3200
# 9993     72.9480
# Name: Profit, Length: 9994, dtype: float64

# %%
len(y)
# Out:
# 9994

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 9994 artists>

# %%
x10=x.head(20)
y10=y.head(20)

# %%
plt.barh(x10,y10)
# Out:
# <BarContainer object of 20 artists>

# %%
plt.bar(x[0:10],y[0:10])
# Out:
# <BarContainer object of 10 artists>

# %%
import pandas as pd
df2=pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx", sheet_name="People")
df2.head(5)
# Out:
#               Person   Region
# 0      Anna Andreadi     West
# 1        Chuck Magee     East
# 2     Kelly Williams  Central
# 3  Cassandra Brandow    South

# %%
dataset = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx", None)
dataset.keys()
# Out:
# dict_keys(['Orders', 'Returns', 'People'])

# %%
dataset = pd.read_excel(r"/content/Sample_-_Superstore-1.xlsx")
dataset.keys()
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
x=dataset['Customer ID']
y=dataset['Profit']

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(x[0:10],y[0:10], hatch='\\')
plt.xlabel('Customer ID')
plt.ylabel('Porfit')
plt.title('Customer ID VS Profit')
plt.text(0.5,50, 'kang min')
# Out:
# Text(0.5, 50, 'kang min')

# %%
plt.bar(x[0:10],y[0:10], hatch='\\')
plt.xlabel('Customer ID')
plt.ylabel('Porfit')
plt.title('Customer ID VS Profit')
#plt.text(2,150, '202010124')
plt.text(2,150, '202010124', fontsize =20, bbox = {'facecolor' : 'red', 'alpha':0.1 })
# Out:
# Text(2, 150, '202010124')

# %%
import matplotlib
x1=dataset['Profit']
y1=dataset['Sales']

plt.plot(x1)
plt.plot(y1)
plt.xlabel('sample/time')
plt.legend(["profit", "sales"], loc="right")

# %%
plt.scatter(y,y1)

# %%
plt.pie(y1)
# Out:
# ([<matplotlib.patches.Wedge at 0x785bdddd6110>,
# ...
# ...
#   Text(0.9699465441447672, 0.5188484378907037, ''),
#   Text(0.9698024085209617, 0.5191177982182291, ''),
#   Text(0.9696606415156916, 0.5193825567877473, ''),
#   Text(0.9694960375684973, 0.519689747001981, ''),
#   Text(0.9693214086899133, 0.5200153907870442, ''),
#   Text(0.9691447405508326, 0.5203445703211091, ''),
#   Text(0.9689321160793699, 0.5207403906266105, ''),
#   Text(0.9688606126679525, 0.5208734138163319, ''),
#   Text(0.9688454509603333, 0.5209016146581508, ''),
#   Text(0.9688287211253129, 0.5209327299399518, ''),
#   Text(0.9688144952780355, 0.520959186250867, ''),
#   Text(0.9686541822956591, 0.5212572063013883, ''),
#   Text(0.9682405685222646, 0.5220250965879725, ''),
#   Text(0.9679689526458022, 0.5225285702368715, ''),
#   Text(0.9678422919788018, 0.522763137431495, ''),
#   Text(0.967712106973973, 0.5230040898654562, ''),
#   Text(0.967615406221738, 0.5231829752986434, ''),
# ...

# %%
plt.pie(y1[0:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x785bd3e7f3d0>,
# ...
#  [Text(1.0610955012063537, 0.2899591994050838, ''),
#   Text(0.3166182562419015, 1.0534480907070543, ''),
#   Text(-0.4964581942041543, 0.981595263541726, ''),
#   Text(-1.0930382633228244, 0.12356113835759344, ''),
#   Text(-0.69635964561084, -0.8515181994324874, ''),
#   Text(-0.6328215722185693, -0.8997426619510815, ''),
#   Text(-0.5803803467967511, -0.9344295869952337, ''),
#   Text(0.40327173751664697, -1.023411894459071, ''),
#   Text(1.0650249499995172, -0.2751760452483571, ''),
#   Text(1.0924794512483118, -0.12840813292072836, '')])

# %%
z1=dataset['Product Name']
plt.pie(y1[0:10],labels=z1[0:10])
# Out:
# ([<matplotlib.patches.Wedge at 0x785bd3c8a9e0>,
# ...
#  [Text(1.0610955012063537, 0.2899591994050838, 'Bush Somerset Collection Bookcase'),
#   Text(0.3166182562419015, 1.0534480907070543, 'Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back'),
#   Text(-0.4964581942041543, 0.981595263541726, 'Self-Adhesive Address Labels for Typewriters by Universal'),
#   Text(-1.0930382633228244, 0.12356113835759344, 'Bretford CR4500 Series Slim Rectangular Table'),
#   Text(-0.69635964561084, -0.8515181994324874, "Eldon Fold 'N Roll Cart System"),
#   Text(-0.6328215722185693, -0.8997426619510815, 'Eldon Expressions Wood and Plastic Desk Accessories, Cherry Wood'),
#   Text(-0.5803803467967511, -0.9344295869952337, 'Newell 322'),
#   Text(0.40327173751664697, -1.023411894459071, 'Mitel 5320 IP Phone VoIP phone'),
#   Text(1.0650249499995172, -0.2751760452483571, 'DXL Angle-View Binders with Locking Rings by Samsill'),
# ...
