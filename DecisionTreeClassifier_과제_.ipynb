# %% [markdown]
# <a href="https://colab.research.google.com/github/lkmsdf159/Colleage-/blob/main/DecisionTreeClassifier_%EA%B3%BC%EC%A0%9C_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import warnings as wr
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

df = pd.read_csv("/content/train.csv")

# %%
cols = ['Name','Ticket','Cabin']
df = df.drop(['Name', 'Ticket', 'Cabin'],axis=1)

# %%
df.fillna(0, inplace = True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   0.0      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 9 columns]

# %%
df = pd.read_csv("/content/train.csv")

le=LabelEncoder()
wr.filterwarnings('ignore')
for col in df.columns:
    if df[col].dtype==np.number:
        continue
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              0         0       2   108    1  22.0      1      0     523
# 1              1         1       0   190    0  38.0      1      0     596
# 2              2         1       2   353    0  26.0      0      0     669
# 3              3         1       0   272    0  35.0      1      0      49
# 4              4         0       2    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          886         0       1   548    1  27.0      0      0     101
# 887          887         1       0   303    0  19.0      0      0      14
# 888          888         0       2   413    0   NaN      1      2     675
# 889          889         1       0    81    1  26.0      0      0       8
# 890          890         0       2   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [891 rows x 12 columns]

# %%
df= df.fillna(method='bfill')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0              0         0       2   108    1  22.0      1      0     523
# 1              1         1       0   190    0  38.0      1      0     596
# 2              2         1       2   353    0  26.0      0      0     669
# 3              3         1       0   272    0  35.0      1      0      49
# 4              4         0       2    15    1  35.0      0      0     472
# ..           ...       ...     ...   ...  ...   ...    ...    ...     ...
# 886          886         0       1   548    1  27.0      0      0     101
# 887          887         1       0   303    0  19.0      0      0      14
# 888          888         0       2   413    0  26.0      1      2     675
# 889          889         1       0    81    1  26.0      0      0       8
# 890          890         0       2   220    1  32.0      0      0     466
#
#         Fare  Cabin  Embarked
# 0     7.2500    147         2
# 1    71.2833     81         0
# 2     7.9250    147         2
# 3    53.1000     55         2
# 4     8.0500    147         2
# ..       ...    ...       ...
# 886  13.0000    147         2
# 887  30.0000     30         2
# 888  23.4500    147         2
# 889  30.0000     60         0
# 890   7.7500    147         1
#
# [891 rows x 12 columns]

# %%
y=df['Survived']
x=df.drop('Survived',axis=1)

# %%
x
# Out:
#      PassengerId  Pclass  Name  Sex   Age  SibSp  Parch  Ticket     Fare  \
# 0              0       2   108    1  22.0      1      0     523   7.2500
# 1              1       0   190    0  38.0      1      0     596  71.2833
# 2              2       2   353    0  26.0      0      0     669   7.9250
# 3              3       0   272    0  35.0      1      0      49  53.1000
# 4              4       2    15    1  35.0      0      0     472   8.0500
# ..           ...     ...   ...  ...   ...    ...    ...     ...      ...
# 886          886       1   548    1  27.0      0      0     101  13.0000
# 887          887       0   303    0  19.0      0      0      14  30.0000
# 888          888       2   413    0  26.0      1      2     675  23.4500
# 889          889       0    81    1  26.0      0      0       8  30.0000
# 890          890       2   220    1  32.0      0      0     466   7.7500
#
#      Cabin  Embarked
# 0      147         2
# 1       81         0
# 2      147         2
# 3       55         2
# 4      147         2
# ..     ...       ...
# 886    147         2
# 887     30         2
# 888    147         2
# 889     60         0
# 890    147         1
#
# [891 rows x 11 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
#1 Model

# %%
x_new=pd.get_dummies(x,columns=['Sex'],dtype=np.int32,drop_first=False)
xTrain,xTest,yTrain,yTest=train_test_split(x_new,y,random_state=42,test_size=0.50)

# %%
len(xTrain)
# Out:
# 445

# %%
len(xTest)
# Out:
# 446

# %%
len(yTrain)
# Out:
# 445

# %%
len(yTest)
# Out:
# 446

# %%
from sklearn.tree import DecisionTreeClassifier
reg=DecisionTreeClassifier()
reg.fit(xTrain,yTrain)
print(reg.score(xTest,yTest))
# Out:
# 0.7780269058295964

# %%
#2 Model

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xTrain = sc.fit_transform(xTrain)
xTest = sc.fit_transform(xTest)

# %%
from sklearn.svm import SVC
model = SVC(kernel = 'linear', random_state = 0)
model.fit(xTrain, yTrain)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
yPred = model.predict(xTest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(yTest, yPred)
# Out:
# 0.8004484304932735

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(yTest, yPred)
# Out:
# array([[233,  34],
#        [ 55, 124]])

# %%
#3 Model

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(xTrain, yTrain)
# Out:
# GaussianNB()

# %%
yPred = model.predict(xTest)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(yTest, yPred)
# Out:
# 0.7869955156950673

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(yTest, yPred)
cm
# Out:
# array([[213,  54],
#        [ 41, 138]])

# %%
# the best model is GaussianNB

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Name  Sex   Age  SibSp  Parch  Ticket  \
# 0            0         0       2   108    1  22.0      1      0     523
# 1            1         1       0   190    0  38.0      1      0     596
# 2            2         1       2   353    0  26.0      0      0     669
# 3            3         1       0   272    0  35.0      1      0      49
# 4            4         0       2    15    1  35.0      0      0     472
#
#       Fare  Cabin  Embarked
# 0   7.2500    147         2
# 1  71.2833     81         0
# 2   7.9250    147         2
# 3  53.1000     55         2
# 4   8.0500    147         2

# %%
X = df.iloc[:, [2, 3]].values
y = df.iloc[:, 4].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 2, kernel = 'rbf')
X_train = kpca.fit_transform(X_train)
X_test = kpca.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
# Predicting the Test set results
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.